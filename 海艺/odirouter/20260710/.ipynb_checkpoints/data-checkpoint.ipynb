# %%
import pandas as pd

# %%
a1 = pd.read_csv('data1.csv', dtype=str)

# %%
a2 = pd.read_csv('data2.csv', dtype=str)

# %%
a3 = pd.read_csv('data3_20260711.csv', dtype=str)

# %%
a4 = pd.read_csv('data3_20260711_2.csv', dtype=str)

# %%
a5 = pd.read_csv('data3_20260711_3.csv', dtype=str)

# %%
a6 = pd.read_csv('data_20260712_1.csv', dtype=str)

# %%
a = pd.concat([a1,a2, a3,a4,a5,a6]).drop_duplicates()

# %%
a
# Out:
#    st_save_date              st_event_name st_event_date st_kafka_offset  \
# 0    2026-07-10     log_page_expose_client    2026-07-10          11_592
# 1    2026-07-10                   st_users    2026-07-10             5_0
# 2    2026-07-10                   st_users    2026-07-10            4_44
# 3    2026-07-10   log_token_consume_server    2026-07-10           7_649
# 4    2026-07-10         log_credits_server    2026-07-10           6_644
# ..          ...                        ...           ...             ...
# 45   2026-07-12      log_page_leave_client    2026-07-12          4_1593
# 46   2026-07-12           log_click_client    2026-07-12         11_1653
# 47   2026-07-12     log_page_expose_client    2026-07-12          5_1695
# 48   2026-07-12  log_element_expose_client    2026-07-12          9_1547
# 49   2026-07-12     log_page_expose_client    2026-07-12          6_1671
#
#    st_source_type                        st_app_key  \
# 0     event_track  618025f4e02aff8f3e35df5d2891cc47
# 1            user  618025f4e02aff8f3e35df5d2891cc47
# 2            user  618025f4e02aff8f3e35df5d2891cc47
# 3     event_track  618025f4e02aff8f3e35df5d2891cc47
# 4     event_track  618025f4e02aff8f3e35df5d2891cc47
# ..            ...                               ...
# 45    event_track  618025f4e02aff8f3e35df5d2891cc47
# 46    event_track  618025f4e02aff8f3e35df5d2891cc47
# 47    event_track  618025f4e02aff8f3e35df5d2891cc47
# 48    event_track  618025f4e02aff8f3e35df5d2891cc47
# 49    event_track  618025f4e02aff8f3e35df5d2891cc47
#
#                                        st_raw_message  \
# 0   {"st_event_name":"log_page_expose_client","st_...
# 1   {"st_role_id":"33","st_event_time":17836530477...
# 2   {"st_account_id":"14","st_role_id":"14","st_sa...
# 3   {"properties":{"window_id":"9ab7666b-d232-4c03...
# 4   {"properties":{"action":"api_call","platform_t...
# ..                                                ...
# 45  {"st_pk_id":"6ef02d59-eb05-4796-b9e4-a9a37f2bd...
# 46  {"st_province":"四川省","st_user_id":"0000e86c-6d...
# 47  {"st_country_code":"CN","st_event_name":"log_p...
# 48  {"st_role_id":"","st_save_time":1783825748,"st...
# 49  {"st_distinct_id":"fab31f5b-0fed-490e-b32f-54d...
#
#                                  st_available_message st_status st_error_type  \
# 0   {"st_event_name":"log_page_expose_client","st_...         3             3
# 1   {"st_role_id":"33","st_event_time":17836530477...         3             3
# 2   {"st_account_id":"14","st_role_id":"14","st_sa...         3             3
# 3   {"st_save_time":1783656369,"st_type":"track","...         3             3
# 4   {"st_save_time":1783655706,"st_role_id":"14","...         3             3
# ..                                                ...       ...           ...
# 45                                                NaN         1           NaN
# 46                                                NaN         1           NaN
# 47                                                NaN         1           NaN
# 48                                                NaN         1           NaN
# 49                                                NaN         1           NaN
#
#                                         st_error_info st_report_time  \
# 0                  {"3":["属性名【model_name】在埋点方案中不存在"]}  1783651398622
# 1   {"3":["属性名【utm_source】在埋点方案中不存在","属性名【channel】...  1783653050499
# 2   {"3":["属性名【utm_source】在埋点方案中不存在","属性名【channel】...  1783656019446
# 3   {"3":["属性名【utm_source】在埋点方案中不存在","属性名【channel】...  1783656370779
# 4   {"3":["属性名【utm_source】在埋点方案中不存在","属性名【channel】...  1783655707746
# ..                                                ...            ...
# 45                                                 {}  1783825791131
# 46                                                 {}  1783825792133
# 47                                                 {}  1783825747802
# 48                                                 {}  1783825751121
# 49                                                 {}  1783825791156
#
#                   st_update_at   st_save_time
# 0   2026-07-10 02:43:18.702838  1783651397000
# 1   2026-07-10 03:10:50.551381  1783653048000
# 2   2026-07-10 04:00:19.529169  1783656018000
# 3   2026-07-10 04:06:10.851041  1783656369000
# 4   2026-07-10 03:55:07.829833  1783655706000
# ..                         ...            ...
# 45  2026-07-12 03:09:51.179104  1783825789000
# 46  2026-07-12 03:09:52.179751  1783825789000
# 47  2026-07-12 03:09:07.851640  1783825744000
# 48  2026-07-12 03:09:11.153726  1783825748000
# 49  2026-07-12 03:09:51.179224  1783825789000
#
# [10972 rows x 14 columns]

# %%
a.columns
# Out:
# Index(['st_save_date', 'st_event_name', 'st_event_date', 'st_kafka_offset',
#        'st_source_type', 'st_app_key', 'st_raw_message',
#        'st_available_message', 'st_status', 'st_error_type', 'st_error_info',
#        'st_report_time', 'st_update_at', 'st_save_time'],
#       dtype='object')

# %%
col = ['st_event_name', 'st_raw_message', 'st_status', 'st_error_info', 'st_available_message']

# %%
a = a[col]

# %%
a
# Out:
#                 st_event_name  \
# 0      log_page_expose_client
# 1                    st_users
# 2                    st_users
# 3    log_token_consume_server
# 4          log_credits_server
# ..                        ...
# 45      log_page_leave_client
# 46           log_click_client
# 47     log_page_expose_client
# 48  log_element_expose_client
# 49     log_page_expose_client
#
#                                        st_raw_message st_status  \
# 0   {"st_event_name":"log_page_expose_client","st_...         3
# 1   {"st_role_id":"33","st_event_time":17836530477...         3
# 2   {"st_account_id":"14","st_role_id":"14","st_sa...         3
# 3   {"properties":{"window_id":"9ab7666b-d232-4c03...         3
# 4   {"properties":{"action":"api_call","platform_t...         3
# ..                                                ...       ...
# 45  {"st_pk_id":"6ef02d59-eb05-4796-b9e4-a9a37f2bd...         1
# 46  {"st_province":"四川省","st_user_id":"0000e86c-6d...         1
# 47  {"st_country_code":"CN","st_event_name":"log_p...         1
# 48  {"st_role_id":"","st_save_time":1783825748,"st...         1
# 49  {"st_distinct_id":"fab31f5b-0fed-490e-b32f-54d...         1
#
#                                         st_error_info  \
# 0                  {"3":["属性名【model_name】在埋点方案中不存在"]}
# 1   {"3":["属性名【utm_source】在埋点方案中不存在","属性名【channel】...
# 2   {"3":["属性名【utm_source】在埋点方案中不存在","属性名【channel】...
# 3   {"3":["属性名【utm_source】在埋点方案中不存在","属性名【channel】...
# 4   {"3":["属性名【utm_source】在埋点方案中不存在","属性名【channel】...
# ..                                                ...
# 45                                                 {}
# 46                                                 {}
# 47                                                 {}
# 48                                                 {}
# 49                                                 {}
#
#                                  st_available_message
# 0   {"st_event_name":"log_page_expose_client","st_...
# 1   {"st_role_id":"33","st_event_time":17836530477...
# 2   {"st_account_id":"14","st_role_id":"14","st_sa...
# 3   {"st_save_time":1783656369,"st_type":"track","...
# 4   {"st_save_time":1783655706,"st_role_id":"14","...
# ..                                                ...
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
#
# [10972 rows x 5 columns]

# %%
a.to_csv('data.csv', index=False)
